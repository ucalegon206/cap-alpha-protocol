# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

# Load data
data_dir = Path('data/raw')
outputs_dir = Path('notebooks/outputs')
outputs_dir.mkdir(exist_ok=True)

# Combine all player rankings CSVs
player_csvs = sorted(data_dir.glob('player_rankings_*.csv'))
print(f"Found {len(player_csvs)} player rankings files")

dfs = []
for p in player_csvs:
    try:
        df = pd.read_csv(p)
        dfs.append(df)
        print(f"  {p.name}: {len(df)} rows")
    except Exception as e:
        print(f"  {p.name}: ERROR - {e}")

player_df = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
print(f"\nTotal player records: {len(player_df)}")
print(player_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 13
#      11 data_dir = Path('data/raw')
#      12 outputs_dir = Path('notebooks/outputs')
# ---> 13 outputs_dir.mkdir(exist_ok=True)
#      15 # Combine all player rankings CSVs
#      16 player_csvs = sorted(data_dir.glob('player_rankings_*.csv'))
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'notebooks/outputs'

# %%
# Load team cap data
team_csvs = sorted(data_dir.glob('spotrac_team_cap_*.csv'))
print(f"Found {len(team_csvs)} team cap files")

team_dfs = []
for p in team_csvs:
    try:
        df = pd.read_csv(p)
        # Extract year from filename
        year = int(p.stem.split('_')[3])
        df['Year'] = year
        team_dfs.append(df)
        print(f"  {p.name}: {len(df)} rows")
    except Exception as e:
        print(f"  {p.name}: ERROR - {e}")

team_df = pd.concat(team_dfs, ignore_index=True) if team_dfs else pd.DataFrame()
print(f"\nTotal team records: {len(team_df)}")
print(team_df.head())

# %% [markdown]
# ## Top 25 Players by Cap Hit (All Time)

# %%
# Top players across all years
top_players = player_df.nlargest(25, 'CapValue')[['Player', 'Team', 'Position', 'CapValue', 'Year']].copy()
top_players['CapValue_M'] = top_players['CapValue'] / 1e6  # Convert to millions

fig = go.Figure(data=[
    go.Bar(
        y=top_players['Player'] + ' (' + top_players['Year'].astype(str) + ')',
        x=top_players['CapValue_M'],
        orientation='h',
        marker=dict(
            color=top_players['CapValue_M'],
            colorscale='Viridis',
            showscale=True
        ),
        text=[f"${v:.1f}M" for v in top_players['CapValue_M']],
        textposition='auto',
    )
])

fig.update_layout(
    title='Top 25 Players by Cap Hit (All Years)',
    xaxis_title='Cap Hit ($M)',
    yaxis_title='Player',
    height=600,
    hovermode='closest',
    template='plotly_white',
)

fig.write_html(outputs_dir / 'top_25_players.html')
fig.show()

print(f"\n✓ Saved to: {outputs_dir / 'top_25_players.html'}")

# %% [markdown]
# ## Team Dead Money Trends by Year

# %%
if 'DeadMoneyTotal' in team_df.columns:
    team_trend = team_df.groupby('Year')['DeadMoneyTotal'].sum().reset_index()
    team_trend['DeadMoneyTotal_B'] = team_trend['DeadMoneyTotal'] / 1e9  # Billions
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=team_trend['Year'],
        y=team_trend['DeadMoneyTotal_B'],
        mode='lines+markers',
        name='Total League Dead Money',
        line=dict(color='#1f77b4', width=3),
        marker=dict(size=8)
    ))
    
    fig.update_layout(
        title='League Total Dead Money by Year',
        xaxis_title='Year',
        yaxis_title='Dead Money ($B)',
        hovermode='x unified',
        template='plotly_white',
    )
    
    fig.write_html(outputs_dir / 'team_dead_money_trend.html')
    fig.show()
    print(f"\n✓ Saved to: {outputs_dir / 'team_dead_money_trend.html'}")
else:
    print("Team dead money column not found; skipping trend chart.")

# %% [markdown]
# ## Summary Statistics by Position

# %%
# Position breakdown
position_stats = player_df.groupby('Position').agg({
    'CapValue': ['count', 'mean', 'median', 'max'],
    'Player': 'count'
}).round(0).astype(int)

position_stats.columns = ['Count', 'Mean Cap ($)', 'Median Cap ($)', 'Max Cap ($)', 'Players']
position_stats = position_stats.sort_values('Mean Cap ($)', ascending=False)

print("\n📊 Cap Hit Statistics by Position:")
print(position_stats.to_string())

# Save as HTML table
html_table = position_stats.to_html()
with open(outputs_dir / 'position_stats.html', 'w') as f:
    f.write(f"<h2>Cap Hit Statistics by Position</h2>{html_table}")
print(f"\n✓ Saved to: {outputs_dir / 'position_stats.html'}")

# %% [markdown]
# ## Top 10 Teams by Total Player Cap Hit (Current Year)

# %%
current_year = player_df['Year'].max()
current_year_data = player_df[player_df['Year'] == current_year]

team_totals = current_year_data.groupby('Team')['CapValue'].agg(['sum', 'count']).reset_index()
team_totals.columns = ['Team', 'Total_Cap', 'Player_Count']
team_totals = team_totals.nlargest(10, 'Total_Cap')
team_totals['Total_Cap_M'] = team_totals['Total_Cap'] / 1e6

fig = go.Figure(data=[
    go.Bar(
        x=team_totals['Team'],
        y=team_totals['Total_Cap_M'],
        marker=dict(color=team_totals['Total_Cap_M'], colorscale='RdYlGn_r'),
        text=[f"${v:.0f}M\n({c} players)" for v, c in zip(team_totals['Total_Cap_M'], team_totals['Player_Count'])],
        textposition='auto',
    )
])

fig.update_layout(
    title=f'Top 10 Teams by Total Player Cap Hit ({current_year})',
    xaxis_title='Team',
    yaxis_title='Total Cap Hit ($M)',
    hovermode='x',
    template='plotly_white',
)

fig.write_html(outputs_dir / f'top_teams_{current_year}.html')
fig.show()
print(f"\n✓ Saved to: {outputs_dir / 'top_teams_{current_year}.html'}")

# %% [markdown]
# ## Data Summary

# %%
print("\n" + "="*70)
print("📊 PRODUCTION ANALYSIS SUMMARY")
print("="*70)

print(f"\n📋 Data Coverage:")
print(f"  Player Records: {len(player_df):,}")
print(f"  Years: {sorted(player_df['Year'].unique())}")
print(f"  Teams: {player_df['Team'].nunique()}")
print(f"  Positions: {player_df['Position'].nunique()}")

print(f"\n💰 Cap Hit Summary:")
print(f"  Total League Cap (All Years): ${player_df['CapValue'].sum()/1e9:.2f}B")
print(f"  Avg Player Cap Hit: ${player_df['CapValue'].mean()/1e6:.2f}M")
print(f"  Median: ${player_df['CapValue'].median()/1e6:.2f}M")
print(f"  Max: ${player_df['CapValue'].max()/1e6:.2f}M")

print(f"\n🏈 Current Year ({current_year}):")
print(f"  Players: {len(current_year_data):,}")
print(f"  Total Cap: ${current_year_data['CapValue'].sum()/1e9:.2f}B")
print(f"  Avg Cap/Player: ${current_year_data['CapValue'].mean()/1e6:.2f}M")

print(f"\n📁 Outputs saved to: {outputs_dir}")
print("\n✅ Analysis complete!")
print("="*70)

# %% [markdown]
# ## Decision Tree: What Drives High Dead Money?
#
# Using a decision tree to identify which player attributes (position, team, year, status) best predict high dead money hits.

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Load dead money data
dead_money_df = pd.read_csv('data/processed/compensation/player_dead_money.csv')

print(f"Dead Money Dataset: {len(dead_money_df)} records")
print(f"Columns: {dead_money_df.columns.tolist()}")
print(f"\nDead Cap Statistics:")
print(dead_money_df['dead_cap_millions'].describe())

# Prepare data for decision tree
df_tree = dead_money_df.copy()

# Encode categorical features
le_position = LabelEncoder()
le_team = LabelEncoder()

df_tree['position_encoded'] = le_position.fit_transform(df_tree['position'])
df_tree['team_encoded'] = le_team.fit_transform(df_tree['team'])
df_tree['is_king_int'] = df_tree['is_king'].astype(int)

# Create features (X) and target (y)
X = df_tree[['position_encoded', 'team_encoded', 'year', 'is_king_int']]
y = df_tree['dead_cap_millions']

# Train decision tree with limited depth for interpretability
dt = DecisionTreeRegressor(max_depth=4, min_samples_split=5, min_samples_leaf=2, random_state=42)
dt.fit(X, y)

print(f"\n✓ Decision Tree Model:")
print(f"  R² Score: {dt.score(X, y):.3f}")
print(f"  Tree Depth: {dt.get_depth()}")
print(f"  Leaf Nodes: {dt.get_n_leaves()}")

# Feature importance
feature_names = ['Position', 'Team', 'Year', 'Is King (High Impact)']
importances = dt.feature_importances_

print(f"\n📊 Feature Importance (What Drives Dead Money):")
for fname, imp in sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True):
    print(f"  {fname:<25} {imp:>6.1%}")

# %%
# Visualize the decision tree
fig, ax = plt.subplots(figsize=(20, 12))
plot_tree(
    dt, 
    feature_names=feature_names,
    filled=True,
    rounded=True,
    fontsize=10,
    ax=ax
)
plt.title('Decision Tree: Predicting Player Dead Money', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(outputs_dir / 'decision_tree_dead_money.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Decision tree visualization saved")

# %% [markdown]
# ## Tree Insights: Decision Rules by Position

# %%
# Analyze dead money by position
position_analysis = dead_money_df.groupby('position').agg({
    'dead_cap_millions': ['count', 'mean', 'median', 'max', 'std']
}).round(2)

position_analysis.columns = ['Count', 'Mean', 'Median', 'Max', 'Std Dev']
position_analysis = position_analysis.sort_values('Mean', ascending=False)

print("📍 Dead Money by Position:")
print(position_analysis.to_string())

# Create visualization
fig = px.box(
    dead_money_df,
    x='position',
    y='dead_cap_millions',
    title='Distribution of Dead Money by Position',
    labels={'dead_cap_millions': 'Dead Cap ($M)', 'position': 'Position'},
    points='all',
)
fig.update_layout(height=500, template='plotly_white')
fig.write_html(outputs_dir / 'dead_money_by_position.html')
fig.show()

print(f"\n✓ Saved: {outputs_dir / 'dead_money_by_position.html'}")

# %% [markdown]
# ## "Dead Money Kings" vs Regular Players
